# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_path="Cosmos/Cosmos/csv_files/fraud_dataset.csv"

# %%
df=pd.read_csv(csv_path)

# %%
df.head()
# Out:
#   transaction_id customer_id  amount  customer_age  past_fraud_count  \
# 0          T1000        C291   46.93          68.0                 0
# 1          T1001        C280  301.01          57.0                 1
# 2          T1002        C321  131.67           NaN                 1
# 3          T1003        C450   91.29          49.0                 0
# 4          T1004        C111   16.96          65.0                 0
#
#    avg_spend  is_international device_type customer_region     category  \
# 0     124.55                 1      mobile           North       travel
# 1     116.49                 0         pos           North       travel
# 2      96.91                 0         web           North      grocery
# 3     108.17                 0         pos            West  electronics
# 4      70.14                 0         pos           South      grocery
#
#   merchant     transaction_time  is_fraud
# 0  Walmart     01/01/2024 08:10         0
# 1      NaN  2024-01-01 07:50:12         0
# 2   Amazon  2024-01-01 18:09:06         0
# 3      NaN     2024/01/01 03:52         0
# 4   Amazon    Jan 01 2024 09:08         0

# %%
df.plot()
# Out:
# <Axes: >

# %%
#Fixing the date and time format.
df['transaction_time'] = pd.to_datetime(df['transaction_time'], format='mixed')
